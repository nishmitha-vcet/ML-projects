# %% [markdown]
# # Salary Prediction based on experience using LinearRegression

# %%
import numpy as np
import pandas as pd

# %%
sal_data=pd.read_csv('Downloads/Salary_Data.csv')

# %%
sal_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
sal_data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
sal_data.describe()#eda
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sal_data.isnull()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
sal_data['Salary'].unique()
# Out:
# array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#         64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#         66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#        109431, 105582, 116969, 112635, 122391, 121872], dtype=int64)

# %%
sal_data['Salary'].value_counts()#value_counts function count the occurrenes of each value in the column.
# Out:
# 56957     1
# 112635    1
# 56642     1
# 60150     1
# 43525     1
# 83088     1
# 81363     1
# 113812    1
# 121872    1
# 122391    1
# 39891     1
# 91738     1
# 64445     1
# 98273     1
# 67938     1
# 37731     1
# 46205     1
# 57189     1
# 61111     1
# 116969    1
# 54445     1
# 66029     1
# 105582    1
# 39343     1
# 55794     1
# 93940     1
# 101302    1
# 109431    1
# 57081     1
# 63218     1
# Name: Salary, dtype: int64

# %%
sal_data.rename(columns={"YearsExperience":"YExp"})
# Out:
#     YExp  Salary
# 0    1.1   39343
# 1    1.3   46205
# 2    1.5   37731
# 3    2.0   43525
# 4    2.2   39891
# 5    2.9   56642
# 6    3.0   60150
# 7    3.2   54445
# 8    3.2   64445
# 9    3.7   57189
# 10   3.9   63218
# 11   4.0   55794
# 12   4.0   56957
# 13   4.1   57081
# 14   4.5   61111
# 15   4.9   67938
# 16   5.1   66029
# 17   5.3   83088
# 18   5.9   81363
# 19   6.0   93940
# 20   6.8   91738
# 21   7.1   98273
# 22   7.9  101302
# 23   8.2  113812
# 24   8.7  109431
# 25   9.0  105582
# 26   9.5  116969
# 27   9.6  112635
# 28  10.3  122391
# 29  10.5  121872

# %%
sal_data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
import matplotlib.pyplot as plt

import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot(sal_data['Salary'],sal_data['YearsExperience'])

#theres a lot of variation in data

# %%
sal_data
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y)
L = LinearRegression().fit(xtrain,ytrain)

print("coef",L.coef_)
print("intercept",L.intercept_)

print("training data",L.score(xtrain,ytrain))
print("testing data",L.score(xtest,ytest))
# Out:
# coef [9556.81960115]
# intercept 26177.279519212716
# training data 0.9523134379030007
# testing data 0.9620883043603904

# %%
plt.figure(figsize=(12,10))
plt.scatter(xtrain,ytrain,color="r",label="training data")
plt.scatter(xtest,ytest,color="b",label="testing data")

plt.plot(xtest,L.predict(xtest))


plt.xlabel("YearsofExperience")
plt.ylabel("salary")
plt.legend(loc=2)
plt.show()
